# %% [markdown]
# ### CSE-221710315009-Ch.Sai Pranathi

# %% [markdown]
# Read the dataset from the below path:
# [clickhere](https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv)
# 1. Analyze the  top 5 cities with highest number of female graduates
# 2. Find the 5 cities with lowest number of female graduates and concatenate the two dataframes of top 5 cities with  bottom 5 cities
# 3. Display only the rows which belong to Kerala, Bihar and Maharashtra.
# 4. Find the  top 10 cities with highest total graduation rate
# 5. Calculate the average child sex ratio of the Kerala State.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Sri\Documents\csv file\cities.csv")
df
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
#Analyze the top 5 cities with highest number of female graduates
high=df.nlargest(5, ['female_graduates']) 
high
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 141              Delhi            7    NCT OF DELHI         99
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 119            Chennai           33      TAMIL NADU          2
#
#      population_total  population_male  population_female  \
# 141          11007835          5871362            5136473
# 185          12478447          6736815            5741632
# 72            8425970          4401299            4024671
# 184           6809970          3500802            3309168
# 119           4681087          2357633            2323454
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 141               1209275               647938                 561337  ...
# 185               1139146               599007                 540139  ...
# ...

# %%
#Find the 5 cities with lowest number of female graduates and concatenate the two dataframes of top 5 cities with 
# bottom 5 cities

# %%
#Display only the rows which belong to Kerala, Bihar and Maharashtra.
g=df.groupby("state_name")
print(g.get_group("BIHAR"))
print(g.get_group("KERALA"))
print(g.get_group("MAHARASHTRA"))
# Out:
#          name_of_city  state_code state_name  dist_code  population_total  \
# 31             Arrah           10      BIHAR         29            261099
# 34        Aurangabad           10      BIHAR         33            101520
# 39            Bagaha           10      BIHAR          1            113012
# 69         Begusarai           10      BIHAR         20            251136
# 73           Bettiah           10      BIHAR          1            132896
# 78         Bhagalpur           10      BIHAR         22            398138
# 98       Biharsharif           10      BIHAR         27            296889
# 111            Buxar           10      BIHAR         30            102591
# 117           Chapra           10      BIHAR         17            201597
# 134        Darbhanga           10      BIHAR         13            294116
# 140            Dehri           10      BIHAR         32            137068
# 153  Dinapur Nizamat           10      BIHAR         28            182241
# ...

# %%
#Find the  top 10 cities with highest total graduation rate
h=df.nlargest(10, ['total_graduates']) 
h
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 141              Delhi            7    NCT OF DELHI         99
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 119            Chennai           33      TAMIL NADU          2
# 274            Kolkata           19     WEST BENGAL         16
# 7            Ahmadabad           24         GUJARAT          7
# 380               Pune           27     MAHARASHTRA         25
# 288            Lucknow            9   UTTAR PRADESH         26
# 225             Jaipur            8       RAJASTHAN         12
#
#      population_total  population_male  population_female  \
# 141          11007835          5871362            5136473
# 185          12478447          6736815            5741632
# 72            8425970          4401299            4024671
# ...

# %%
#Calculate the average child sex ratio of the Kerala State.
g=df.groupby("state_name")
if('state_name'=="KERALA"):
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-98f63446c9f8> in <module>
#       2 g=df.groupby("state_name")
#       3 f=g.get_group("KERALA")
# ----> 4 df.f.mean(axis=10)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'f'
